# %% [markdown]
# <img src='https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcQ-VfNtOyJbsaxu43Kztf_cv1mgBG6ZIQZEVw&usqp=CAU'>
#
# # Procesamiento de Lenguage Natural
#
# ## Taller #5: TF-IDF
#
# # Fabio Peña

# %%
import re
import numpy as np
import pandas as pd

from nltk.corpus import stopwords
stopwords_sp = stopwords.words('spanish')
from nltk.stem.snowball import SnowballStemmer
spanishStemmer=SnowballStemmer("spanish")
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics.pairwise import cosine_distances
import seaborn as sn
import matplotlib.pyplot as plt

# %% [markdown]
# # Punto 1: Pre-Procesamiento
#
# - `[18 pts]` Leer el archivo `Princesas.csv` usando `pandas` y crear una nueva columna con el texto en minúscula, sin caracteres especiales ni números, sin palabras vacias y hacer stemming de las palabras

# %%
# data
datos_p = pd.read_csv(r'./Princesas.csv')
datos_p
# Out:
#        Princesa                                       Personalidad
# 0  Blancanieves  Blancanieves es una princesa de noble cuna que...
# 1    Cenicienta  Cenicienta es inicialmente una sirvienta en su...
# 2        Aurora  La Princesa Aurora, la Bella Durmiente, es la ...
# 3         Bella  Bella es una muchacha que vive en la campiña f...
# 4        Jasmín  Cuando se introdujo por primera vez, la Prince...
# 5    Pocahontas  El nombre de Pocahontas significa "Pequeña Sil...
# 6         Mulan  Mulan es atípica a los anteriores papeles feme...
# 7         Tiana  Es una joven camarera que sueña con ser dueña ...
# 8        Mérida  Mérida llama la atención por su característico...
# 9         Moana  Moana, una joven de 16 años de edad, hija únic...

# %%
# data procesada
def p_texs(tex):
    tex = tex.lower()
    tex = re.sub(r"[\W\d_]+", " ", tex)
    tex = " ".join([palabra for palabra in tex.split() if palabra not in stopwords_sp])
    tex = " ".join([spanishStemmer.stem(palabra) for palabra in tex.split()])
    return tex

datos_p['pre-procesado'] = datos_p['Personalidad'].apply(lambda tex: p_texs(tex))
datos_p
# Out:
#        Princesa                                       Personalidad  \
# 0  Blancanieves  Blancanieves es una princesa de noble cuna que...
# 1    Cenicienta  Cenicienta es inicialmente una sirvienta en su...
# 2        Aurora  La Princesa Aurora, la Bella Durmiente, es la ...
# 3         Bella  Bella es una muchacha que vive en la campiña f...
# 4        Jasmín  Cuando se introdujo por primera vez, la Prince...
# 5    Pocahontas  El nombre de Pocahontas significa "Pequeña Sil...
# 6         Mulan  Mulan es atípica a los anteriores papeles feme...
# 7         Tiana  Es una joven camarera que sueña con ser dueña ...
# 8        Mérida  Mérida llama la atención por su característico...
# 9         Moana  Moana, una joven de 16 años de edad, hija únic...
#
#                                        pre-procesado
# 0  blancaniev princes nobl cun ve forz servidumbr...
# 1  cenicient inicial sirvient cas constant objet ...
# 2  princes auror bell durmient hij unic rein flor...
# ...

# %% [markdown]
# # Punto 2: TF-IDF
#
# - `[16 pts]` Crear la matriz TF-IDF

# %%
# tfidf_matrix
matriz_vector = TfidfVectorizer()
tfid_princess = matriz_vector.fit_transform(datos_p['pre-procesado'].values)
tfid_princess_m = pd.DataFrame(tfid_princess.toarray(), columns=matriz_vector.get_feature_names())
tfid_princess_m.index = datos_p['Princesa'].values
tfid_princess_m.T.round(3)
# Out:
#          Blancanieves  Cenicienta  Aurora  Bella  Jasmín  Pocahontas  Mulan  \
# abrum           0.000         0.0   0.065  0.000   0.000       0.000    0.0
# abuel           0.000         0.0   0.000  0.000   0.000       0.000    0.0
# acuerd          0.000         0.0   0.056  0.000   0.000       0.000    0.0
# ademas          0.000         0.0   0.000  0.000   0.000       0.099    0.0
# afortun         0.087         0.0   0.000  0.000   0.000       0.000    0.0
# ...               ...         ...     ...    ...     ...         ...    ...
# viv             0.000         0.0   0.000  0.074   0.000       0.000    0.0
# volunt          0.000         0.0   0.000  0.000   0.161       0.000    0.0
# volv            0.000         0.0   0.065  0.000   0.000       0.000    0.0
# vudu            0.000         0.0   0.000  0.000   0.000       0.000    0.0
# wak             0.000         0.0   0.000  0.000   0.000       0.000    0.0
#
#          Tiana  Mérida  Moana
# ...

# %% [markdown]
# # Punto 3: Distancia del coseno
# - `[12 pts]` Calcular la distancia del coseno entre cada una de las princesas
# - `[2 pts]` ¿Cuáles son las princesas más parecidas?
# - `[2 pts]` ¿Cuáles son las princesas más diferentes?

# %%
# dist_cos
dist_cos = cosine_distances(tfid_princess_m.values)
dist_cos = pd.DataFrame(dist_cos
                                        , columns = tfid_princess_m.T.columns
                                        , index = tfid_princess_m.T.columns)
dist_cos
# Out:
#               Blancanieves  Cenicienta    Aurora     Bella    Jasmín  \
# Blancanieves      0.000000    0.846412  0.842647  0.918152  0.935368
# Cenicienta        0.846412    0.000000  0.858739  0.947104  0.959291
# Aurora            0.842647    0.858739  0.000000  0.833179  0.937415
# Bella             0.918152    0.947104  0.833179  0.000000  0.888222
# Jasmín            0.935368    0.959291  0.937415  0.888222  0.000000
# Pocahontas        0.922360    0.960478  0.869588  0.890872  0.942943
# Mulan             0.884287    0.932651  0.919588  0.881828  0.935293
# Tiana             0.960222    0.918932  0.939219  0.973240  0.937768
# Mérida            0.985292    0.970976  0.941046  0.943696  0.972673
# Moana             0.951577    0.974964  0.966101  0.923915  0.969241
#
#               Pocahontas     Mulan     Tiana    Mérida     Moana
# Blancanieves    0.922360  0.884287  0.960222  0.985292  0.951577
# Cenicienta      0.960478  0.932651  0.918932  0.970976  0.974964
# ...

# %%
fig, ax = plt.subplots(figsize=(12,12))
sn.heatmap(dist_cos, annot=True, vmin=0.1, vmax=0.99, fmt=".6f",ax=ax)

# %% [markdown]
# [2 pts] ¿Cuáles son las princesas más parecidas?
#
#
# *Aurora y Bella
#
# *Blancanieves y Aurora
#
# *Blancanieves y Cenicienta
#
#
# [2 pts] ¿Cuáles son las princesas más diferentes?
#
#
# *Tiana y Mulán
#
#
# *Mérida y Mulán
